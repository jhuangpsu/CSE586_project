# %% [markdown]
# # Preparation

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
# %cd ./drive/MyDrive/Colab\ Notebooks/cascade-stereo
# Out:
# /content/drive/MyDrive/Colab Notebooks/cascade-stereo

# %%
# !pip install -r requirements.txt --user
# Out:
# ...
#      |████████████████████████████████| 748.9 MB 658 bytes/s
# ...
#      |████████████████████████████████| 48 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 125 kB 95.0 MB/s
# ...
#   WARNING: The scripts convert-caffe2-to-onnx and convert-onnx-to-caffe2 are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.2.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.2.0 which is incompatible.
# ...

# %%
# %cd ./CasMVSNet
# Out:
# /content/drive/MyDrive/Colab Notebooks/cascade-stereo/CasMVSNet

# %%
# !unzip mvs_training.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: mvs_training/Depths_raw/scan93/depth_visual_0005.png
#   inflating: __MACOSX/mvs_training/Depths_raw/scan93/._depth_visual_0005.png
#   inflating: mvs_training/Depths_raw/scan93/depth_visual_0004.png
#   inflating: __MACOSX/mvs_training/Depths_raw/scan93/._depth_visual_0004.png
#   inflating: mvs_training/Depths_raw/scan93/depth_visual_0010.png
#   inflating: __MACOSX/mvs_training/Depths_raw/scan93/._depth_visual_0010.png
#   inflating: mvs_training/Depths_raw/scan93/depth_visual_0038.png
#   inflating: __MACOSX/mvs_training/Depths_raw/scan93/._depth_visual_0038.png
#   inflating: mvs_training/Depths_raw/scan93/depth_map_0044.pfm
#   inflating: __MACOSX/mvs_training/Depths_raw/scan93/._depth_map_0044.pfm
#   inflating: mvs_training/Depths_raw/scan93/depth_map_0050.pfm
#   inflating: __MACOSX/mvs_training/Depths_raw/scan93/._depth_map_0050.pfm
#   inflating: mvs_training/Depths_raw/scan93/depth_map_0046.pfm
# ...

# %%
# !git clone https://github.com/NVIDIA/apex.git
# %cd './apex'
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./
# %cd ..
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 9585, done.
# remote: Counting objects: 100% (656/656), done.
# remote: Compressing objects: 100% (445/445), done.
# remote: Total 9585 (delta 381), reused 388 (delta 194), pack-reused 8929
# Receiving objects: 100% (9585/9585), 14.82 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (6494/6494), done.
# Checking out files: 100% (430/430), done.

# %% [markdown]
# # Training

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab Notebooks/cascade-stereo/CasMVSNet'

# %%
# !export NGPUS=8

# %%
# !export save_results_dir="./checkpoints"

# %%
# !chmod 755 -R './train.sh'

# %%
# !./train.sh $NGPUS $save_results_dir  --ndepths "48,32,8"  --depth_inter_r "4,2,1"   --dlossw "0.5,1.0,2.0"  --batch_size 1 --eval_freq 3
# Out:
# current time 20220419_052823
# creating new summary file
# argv: ['--local_rank=0', '--logdir', '20,14,8', '--dataset=dtu_yao', '--batch_size=1', '--trainpath=./mvs_training/', '--trainlist', 'lists/dtu/train.txt', '--testlist', 'lists/dtu/test.txt', '--numdepth=192', '--depth_inter_r', '4,2,1', '--dlossw', '0.5,1.0,2.0', '--batch_size', '1', '--eval_freq', '3']
# ################################  args  ################################
# mode      	train                         	<class 'str'>
# model     	mvsnet                        	<class 'str'>
# device    	cuda                          	<class 'str'>
# dataset   	dtu_yao                       	<class 'str'>
# trainpath 	./mvs_training/               	<class 'str'>
# testpath  	./mvs_training/               	<class 'str'>
# trainlist 	lists/dtu/train.txt           	<class 'str'>
# testlist  	lists/dtu/test.txt            	<class 'str'>
# epochs    	3                             	<class 'int'>
# ...

# %% [markdown]
# # Testing

# %%
# !export save_results_dir="./outputs"

# %%
# !chmod 755 -R './test.sh'

# %%
# !git clone https://github.com/YoYo000/fusibile.git
# Out:
# Cloning into 'fusibile'...
# remote: Enumerating objects: 85, done.
# remote: Total 85 (delta 0), reused 0 (delta 0), pack-reused 85
# Unpacking objects: 100% (85/85), done.

# %%
#!./test.sh  $CKPT_FILE --outdir $save_results_dir  --interval_scale 1.06  --filter_method gipuma
# !./test.sh  $CKPT_FILE --outdir $save_results_dir  --interval_scale 1.06
# Out:
# argv: ['--dataset=general_eval', '--batch_size=1', '--testpath=./mvs_customized/lab', '--testlist=./mvs_customized/test.txt', '--loadckpt', './casmvsnet.ckpt', '--interval_scale', '1.06', '--filter_method', 'gipuma']
# ################################  args  ################################
# model     	mvsnet                        	<class 'str'>
# dataset   	general_eval                  	<class 'str'>
# testpath  	./mvs_customized/lab          	<class 'str'>
# testpath_single_scene	None                          	<class 'NoneType'>
# testlist  	./mvs_customized/test.txt     	<class 'str'>
# batch_size	1                             	<class 'int'>
# numdepth  	192                           	<class 'int'>
# loadckpt  	./casmvsnet.ckpt              	<class 'str'>
# outdir    	./outputs                     	<class 'str'>
# display   	False                         	<class 'bool'>
# share_cr  	False                         	<class 'bool'>
# ...
